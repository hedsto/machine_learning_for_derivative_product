# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

from scipy.optimize import minimize
from scipy.optimize import least_squares

# %%
from numpy.random import default_rng, SeedSequence

sq = SeedSequence()
seed = sq.entropy        # on sauve la graine pour reproduire les résultats
print('seed = ', seed)
rng = default_rng(sq)
rng.standard_normal(5)
# Out:
# seed =  251591266078601047453343575499368904122
# array([ 0.23925415,  0.18966351, -0.28271264,  0.73880656, -2.09208158])

# %%
sns.set_style("whitegrid")
mpl.rcParams['figure.dpi'] = 100

params_grid = {"color": 'lightgrey', "linestyle": 'dotted', "linewidth": 0.7 }

# %%
# Pamètre du model
N = 10
M = 10000

T = 1
dt = T/N
S0 = 100
K = 100
sigma = 0.1
r = 0.04
m = 3

# %% [markdown]
# Comparer le LS avec régression linéaire et le LS lorsqu'on utilise un réseau de neurones (régression non-linéaire) pour apprendre la fonction de continuation. C'est un travail numérique prospectif à faire pour le mardi 19 mars en s'interrogeant sur les différents paramètres: nombres de scénarios, nombre d'epochs, taille de batch, réglage du learning rate, normalisation des données simulées...

# %% [markdown]
# Programmer l'algorithme de Longstaff-Schwartz (celui vu en cours, le dernier!) pour un Put bermudéen dans un modèle de Black-Scholes, c'est à dire un put que l'on peut exercer aux dates $k/N$, $k=0,\dots,N$. On prendra $r=0.04$, $\sigma=0.1$, $x_0=100$ et le strike $K=100$ avec $N=10$ dates jusqu'en $T=1$ et le payoff $\phi_k(x) = e^{-r k/N}(K-x)_+$.

# %% [markdown]
# Pour cela on va reprendre le code utiliser pour le TP2 :

# %%
def brownian_1d(n_times: int, n_paths: int,
                final_time: float=1.0,
                increments: bool=False,
                random_state: np.random.Generator=rng) -> np.array:
    """Simulate paths of standard Brownian motion
    Args:
        n_times: Number of timesteps
        n_paths: Number of paths
        final_time: Final time of simulation
        increments: If `True` the increments of the paths are returned.
        random_state: `np.random.Generator` used for simulation
    Returns:
        `np.array` of shape `(n_times+1, n_paths)` containing the paths if the argument `increments` is `False`
        `np.array` of shape `(n_times, n_paths)` containing the increments if the argument `increments` is `True`
    """
    dB = np.sqrt(final_time / n_times) * random_state.standard_normal((n_times, n_paths))
    if increments:
        return dB
    else:
        brownian = np.zeros((n_times+1, n_paths))
        brownian[1:] = np.cumsum(dB, axis=0)
        return brownian

def black_scholes_1d(n_times: int, n_paths: int,
                     final_time: float=1.0,
                     random_state: np.random.Generator=rng, *,
                     init_value: float,
                     r: float, sigma: float) -> np.array:
    """Simulate paths of Black-Scholes process
    Args:
        n_times: Number of timesteps
        n_paths: Number of paths
        final_time: Final time of simulation
        init_value: `S0`
        r: Interest rate
        sigma: Volatility
        random_state: `np.random.Generator` used for simulation
    Returns:
        `np.array` of shape `(n_times+1, n_paths)` containing the paths
    """
    Bt = brownian_1d(n_times, n_paths)
    times = np.arange(n_times+1)*(1/n_times)
    t = times[:, np.newaxis]
    St = init_value * np.exp((r - 0.5*sigma**2)*t + sigma*Bt)
    return St

# %% [markdown]
# Pour trouver la valeur $V_0$, on applique la récurrence backward suivante :
#
# $V_N(x) = \phi_N(x)$
#
# et $V_n(x) = max(\phi_n(x), \Phi(x,\theta_n))$
#
# avec $\theta_n = argmin_\theta \sum_{j=1}^{M} \left( V_{n+1}(X_{n+1}^{(j)}) - \Phi(X_{n}^{(j)}, \theta) \right)^2$
#
# pour $\Phi$ on a choisis des fonctions polynomiales de degrées m :
#
# $\Phi(x) = \theta_0+\theta_1*x+\theta_2*x^2 + ... + \theta_m*x^m$

# %%
# psi est ma régression linéaire qui va me permettre d'approcher le résultat théorique
# Le but étant de trouver les theta optimaux
def psi(x, theta, m):
    res = 0
    for i in range(m):
      res += theta[i]*(x**i)
    return res

def phi(x, K, k, N):
    return np.exp(-r*k/N)*np.maximum(K-x, 0)

#meme fonction que la précédente mais elle me permet de manipuler des tableaux
#et sera donc utile lorsque je ferai une régression pour trouver theta à partir d'une simulation de prix Black Scholes
def phi_regression(x, K, k, N):
    return np.exp(-r*k/N)*np.maximum(K-x[k], 0)

#Fonction dont on cherche l'argmin theta
def objective_function(theta, M, S, n, K, thetas):
    result = 0
    for j in range(M):
        result += (V(S[n+1][j], n+1, thetas[-1], N, K) - psi(S[n][j], theta, K))**2
    return result/M

def V(x, n, theta,N, K):
    if n == N:
        return phi(x,K,N,N)
    else:
        return max(phi(x, K,n,N), psi(x, theta, K))

def simulate_V(S,K,r,n,V):
    if n==-1:
        return V
    else :
        V[n] = np.maximum(phi_regression(S,K,n,N),V[n+1])
        return simulate_V(S,K,r,n-1,V)

# %% [markdown]
# # Régression Linéaire

# %%
def regression_theta(X_t, M, m, n):
    e_m_X = []
    for j in range(M):
        e_m_X_j = [X_t[n][j]**k for k in range(m)]

        e_m_X.append(np.array(e_m_X_j).reshape(-1, 1))
    #print(e_m_X[2])
    A_n_m_M = np.zeros((e_m_X[0].dot(e_m_X[0].T).shape))
    for i in range(M):
        A_n_m_M += e_m_X[j].dot(e_m_X[j].T)
    A_n_m_M = (1/M) * A_n_m_M
    print(A_n_m_M)
    #A_n_m_M = sum(e_m_X[j].dot(e_m_X[j].T) for j in range(M)) / M
    e_m_X = np.array(e_m_X)
    V_simu = np.zeros_like(X_t)
    V_simu[-1] = phi_regression(X_t, K, N, N)
    Z_n_m =  np.array([simulate_V(X_t[:,j],K,r,V_simu.shape[0]-2,V_simu) for j in range(M)])
    print(Z_n_m.shape)
    esperance = [0 for _ in range(m)]
    for j in range(M-1):
        for k in range(m):
            esperance[k] += Z_n_m[n+1][Z_n_m.shape[1]-1][j]* e_m_X[j][k][0]
    esperance = [esperance[k] / M for k in range(m)]

    #print([np.sum(Z_n_m[0][j][n+1] * e_m_X[j]) / M for j in range(M)])
    theta_n_m_M = np.linalg.inv(A_n_m_M+0.00001*np.identity(len(A_n_m_M[0]))).dot(esperance)
    return theta_n_m_M

def longstaff_Schwartz_regression(x0, K, T, N, M, m):
    V_hat = [phi(x0, K,N, N)]
    S_t = black_scholes_1d(n_times=N, n_paths=M, final_time= T, init_value=x0, r = r, sigma = sigma)
    thetas = []#[0 for _ in range(m)]#Peut importe les valeurs, on V_N ne dépend pas de theta
    for n in reversed(range(N)):
        print(n)
        #initial_theta = np.ones(4)

        #theta = minimize(objective_function, initial_theta, args=(M, S_t, n, K, thetas))
        theta = regression_theta(S_t, M, m, n)
        optimized_theta = theta#.x
        print(optimized_theta)
        V_hat.append(max(phi(x0, K,n,N), psi(x0, optimized_theta, m)))
        thetas.append(optimized_theta)
    return V_hat, thetas, S_t

# %%
V_hat, thetas, S_t = longstaff_Schwartz_regression(S0, K, T, N, M, 3)
print(V_hat)
# Out:
# 9
# [[1.00000000e+00 9.75736042e+01 9.52060823e+03]
#  [9.75736042e+01 9.52060823e+03 9.28960059e+05]
#  [9.52060823e+03 9.28960059e+05 9.06419811e+07]]
# (2000, 11, 2000)
# [  28299.23900871 1301020.19466677  -13336.70325867]
# 8
# [[1.00000000e+00 9.43123059e+01 8.89481104e+03]
#  [9.43123059e+01 8.89481104e+03 8.38890139e+05]
#  [8.89481104e+03 8.38890139e+05 7.91176634e+07]]
# (2000, 11, 2000)
# [  9371.09549043 406053.25664417  -4306.46449459]
# 7
# [[1.00000000e+00 9.08153418e+01 8.24742630e+03]
#  [9.08153418e+01 8.24742630e+03 7.48992839e+05]
#  [8.24742630e+03 7.48992839e+05 6.80200406e+07]]
# (2000, 11, 2000)
# [ -11863.70145677 -580233.32582195    6390.59409356]
# 6
# [[1.00000000e+00 9.22769694e+01 8.51503908e+03]
#  [9.22769694e+01 8.51503908e+03 7.85742000e+05]
#  [8.51503908e+03 7.85742000e+05 7.25058905e+07]]
# (2000, 11, 2000)
# [  -9162.98935494 -462802.53090896    5016.43972111]
# 5
# [[1.00000000e+00 8.64457533e+01 7.47286826e+03]
#  [8.64457533e+01 7.47286826e+03 6.45997726e+05]
#  [7.47286826e+03 6.45997726e+05 5.58437600e+07]]
# (2000, 11, 2000)
# [  -46596.16736982 -2143816.59424265    24805.79514853]
# 4
# [[1.00000000e+00 8.77266890e+01 7.69597196e+03]
#  [8.77266890e+01 7.69597196e+03 6.75142139e+05]
#  [7.69597196e+03 6.75142139e+05 5.92279844e+07]]
# (2000, 11, 2000)
# [  -44353.2732236  -2067000.4109711     23567.58301918]
# 3
# [[1.00000000e+00 8.95257942e+01 8.01486783e+03]
#  [8.95257942e+01 8.01486783e+03 7.17537408e+05]
#  [8.01486783e+03 7.17537408e+05 6.42381063e+07]]
# (2000, 11, 2000)
# [  -39570.20359159 -1870792.26071492    20901.62175286]
# 2
# [[1.00000000e+00 9.28737306e+01 8.62552983e+03]
#  [9.28737306e+01 8.62552983e+03 8.01085134e+05]
#  [8.62552983e+03 8.01085134e+05 7.43997649e+07]]
# (2000, 11, 2000)
# [  -26024.14567708 -1260711.45701305    13577.48510291]
# 1
# [[1.00000000e+00 9.57606747e+01 9.17010682e+03]
#  [9.57606747e+01 9.17010682e+03 8.78135616e+05]
#  [9.17010682e+03 8.78135616e+05 8.40908591e+07]]
# (2000, 11, 2000)
# [ -15768.14724405 -778662.04646456    8133.05394557]
# 0
# [[1.e+00 1.e+02 1.e+04]
#  [1.e+02 1.e+04 1.e+06]
#  [1.e+04 1.e+06 1.e+08]]
# (2000, 11, 2000)
# [1.83340423e-07 2.19998931e-06 2.20430344e-04]
# [0.0, 0.0, 0.0, 5870744.651911482, 3874981.130808413, 33629695.893630326, 28931435.821466655, 21897421.253477603, 9677681.182131067, 3448566.661977187, 2.20452362548831]

# %%
print("Le prix d'un Put bermudéen avec régression est ", V_hat[-1], "$")
# Out:
# Le prix d'un Put bermudéen avec régression est  2.20452362548831 $

# %% [markdown]
# J'obtiens donc un résultat proche du résultat théorique (environ 2.6$). Cela est sans doute du au fait que ma régression n'est qu'une approximation des formules théoriques mais aussi au fait qu'on approche les espérance par des MC.

# %% [markdown]
# ## Réseaux de neurones

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.17.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 28.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 47.3 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.1 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.3 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.3 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105

# %%
## Redéfinition des fonctions versions pytorch
def V_pytorch(x, n, models, N, K):
    if n==N:
        return torch.tensor(phi(x,K,n,N))
    else :

        return torch.tensor(np.maximum(phi(x,K,n,N),models[n].forward(torch.tensor(x, dtype=torch.float32).unsqueeze(1))))

# %%
import torch
from torch import nn
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

m = 4
class NeuralNetwork(nn.Module):
    def __init__(self,m):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(1, m),
            nn.ReLU(),
            nn.Linear(m, m),
            nn.ReLU(),
            nn.Linear(m, m),
            nn.ReLU(),
            nn.Linear(m, 1)
        )



    def forward(self, x):
        out = self.linear_relu_stack(x)
        return out

# %%
# Ici on entrainer notre réseau de neurone en utilisant la loss :
def nn_loss(model, S_t, K, n, N, models):
    yy = V_pytorch(S_t[n+1], n+1, models, N, K)
    S_n = torch.tensor(S_t[n], dtype=torch.float32).unsqueeze(1)
    xx = model.forward(S_n)
    loss = ((yy - xx) ** 2).mean()
    return loss

M_nn=2000

def longstaff_Schwartz_nn(x0, K, T, N, M, m, num_epochs):

    S_t = black_scholes_1d(n_times=N, n_paths=M, final_time= T, init_value=S0, r = r, sigma = sigma)
    models = np.array([NeuralNetwork(m) for i in range(N)])
    for i in reversed(range(N)):
        model = NeuralNetwork(m)
        optimizer = optim.SGD(model.parameters(), lr=0.01)
        losses = []
        for epoch in range(num_epochs):
            loss = nn_loss(model, S_t, K, i, N, models)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            losses.append(loss.item())
            print(epoch)
            print(loss)
        for param in model.parameters():
            param.requires_grad_(False)
        models[i] = model
    price = max(phi(S0, K,0,N), models[0].forward(torch.tensor(S0, dtype=torch.float32).unsqueeze(-1)))
    return price

# %%
price = longstaff_Schwartz_nn(S0, K, T, N, M_nn, 4, 200)
print(price)
# Out:
# 0
# tensor(22.7521, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 1
# tensor(22.5147, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 2
# tensor(22.2868, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 3
# tensor(22.0678, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 4
# tensor(21.8574, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 5
# tensor(21.6551, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 6
# tensor(21.4604, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 7
# tensor(21.2730, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 8
# tensor(21.0925, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 9
# tensor(20.9187, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 10
# tensor(20.7511, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 11
# tensor(20.5897, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 12
# tensor(20.4340, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 13
# tensor(20.2840, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 14
# tensor(20.1393, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 15
# tensor(19.9998, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 16
# tensor(19.8653, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 17
# tensor(19.7357, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 18
# tensor(19.6107, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 19
# tensor(19.4903, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 20
# tensor(19.3743, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 21
# tensor(19.2626, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 22
# tensor(19.1550, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 23
# tensor(19.0516, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 24
# tensor(18.9521, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 25
# tensor(18.8565, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 26
# tensor(18.7647, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 27
# tensor(18.6766, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 28
# tensor(18.5922, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 29
# tensor(18.5113, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 30
# tensor(18.4339, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 31
# tensor(18.3599, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 32
# tensor(18.2892, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 33
# tensor(18.2218, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 34
# tensor(18.1575, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 35
# tensor(18.0964, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 36
# tensor(18.0383, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 37
# tensor(17.9831, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 38
# tensor(17.9308, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 39
# tensor(17.8813, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 40
# tensor(17.8345, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 41
# tensor(17.7903, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 42
# tensor(17.7486, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 43
# tensor(17.7094, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 44
# tensor(17.6725, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 45
# tensor(17.6379, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 46
# tensor(17.6055, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 47
# tensor(17.5752, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 48
# tensor(17.5468, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 49
# tensor(17.5203, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 50
# tensor(17.4957, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 51
# tensor(17.4727, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 52
# tensor(17.4514, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 53
# tensor(17.4316, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 54
# tensor(17.4133, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 55
# tensor(17.3963, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 56
# tensor(17.3806, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 57
# tensor(17.3662, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 58
# tensor(17.3528, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 59
# tensor(17.3405, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 60
# tensor(17.3293, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 61
# tensor(17.3189, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 62
# tensor(17.3094, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 63
# tensor(17.3007, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 64
# tensor(17.2927, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 65
# tensor(17.2854, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 66
# tensor(17.2788, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 67
# tensor(17.2727, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 68
# tensor(17.2671, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 69
# tensor(17.2621, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 70
# tensor(17.2575, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 71
# tensor(17.2533, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 72
# tensor(17.2495, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 73
# tensor(17.2461, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 74
# tensor(17.2430, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 75
# tensor(17.2401, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 76
# tensor(17.2376, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 77
# tensor(17.2353, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 78
# tensor(17.2332, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 79
# tensor(17.2313, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 80
# tensor(17.2296, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 81
# tensor(17.2280, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 82
# tensor(17.2266, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 83
# tensor(17.2254, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 84
# tensor(17.2242, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 85
# tensor(17.2232, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 86
# tensor(17.2223, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 87
# tensor(17.2215, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 88
# tensor(17.2207, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 89
# tensor(17.2200, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 90
# tensor(17.2194, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 91
# tensor(17.2189, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 92
# tensor(17.2184, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 93
# tensor(17.2180, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 94
# tensor(17.2176, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 95
# tensor(17.2172, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 96
# tensor(17.2169, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 97
# tensor(17.2166, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 98
# tensor(17.2164, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 99
# tensor(17.2161, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 100
# tensor(17.2159, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 101
# tensor(17.2157, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 102
# tensor(17.2156, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 103
# tensor(17.2154, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 104
# tensor(17.2153, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 105
# tensor(17.2152, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 106
# tensor(17.2151, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 107
# tensor(17.2150, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 108
# tensor(17.2149, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 109
# tensor(17.2148, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 110
# tensor(17.2147, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 111
# tensor(17.2147, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 112
# tensor(17.2146, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 113
# tensor(17.2146, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 114
# tensor(17.2145, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 115
# tensor(17.2145, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 116
# tensor(17.2145, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 117
# tensor(17.2144, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 118
# tensor(17.2144, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 119
# tensor(17.2144, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 120
# tensor(17.2144, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 121
# tensor(17.2143, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 122
# tensor(17.2143, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 123
# tensor(17.2143, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 124
# tensor(17.2143, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 125
# tensor(17.2143, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 126
# tensor(17.2143, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 127
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 128
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 129
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 130
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 131
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 132
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 133
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 134
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 135
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 136
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 137
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 138
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 139
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 140
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 141
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 142
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 143
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 144
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 145
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 146
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 147
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 148
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 149
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 150
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 151
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 152
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 153
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 154
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 155
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 156
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 157
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 158
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 159
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 160
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 161
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 162
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 163
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 164
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 165
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 166
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 167
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 168
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 169
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 170
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 171
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 172
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 173
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 174
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 175
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 176
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 177
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 178
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 179
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 180
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 181
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 182
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 183
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 184
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 185
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 186
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 187
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 188
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 189
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 190
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 191
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 192
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 193
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 194
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 195
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 196
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 197
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 198
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 199
# tensor(17.2142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 0
# tensor(25.5575, dtype=torch.float64, grad_fn=<MeanBackward0>)
# <ipython-input-78-69b186ae4514>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(np.maximum(phi(x,K,n,N),models[n].forward(torch.tensor(x, dtype=torch.float32).unsqueeze(1))))
# 1
# tensor(24.9341, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 2
# tensor(24.3635, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 3
# tensor(23.8204, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 4
# tensor(23.3025, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 5
# tensor(22.8081, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 6
# tensor(22.3355, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 7
# tensor(21.8833, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 8
# tensor(21.4502, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 9
# tensor(21.0352, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 10
# tensor(20.6374, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 11
# tensor(20.2557, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 12
# tensor(19.8895, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 13
# tensor(19.5379, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 14
# tensor(19.2002, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 15
# tensor(18.8759, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 16
# tensor(18.5642, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 17
# tensor(18.2646, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 18
# tensor(17.9765, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 19
# tensor(17.6995, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 20
# tensor(17.4330, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 21
# tensor(17.1766, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 22
# tensor(16.9299, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 23
# tensor(16.6923, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 24
# tensor(16.4635, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 25
# tensor(16.2431, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 26
# tensor(16.0308, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 27
# tensor(15.8262, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 28
# tensor(15.6289, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 29
# tensor(15.4387, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 30
# tensor(15.2552, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 31
# tensor(15.0782, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 32
# tensor(14.9074, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 33
# tensor(14.7424, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 34
# tensor(14.5832, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 35
# tensor(14.4294, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 36
# tensor(14.2809, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 37
# tensor(14.1374, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 38
# tensor(13.9988, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 39
# tensor(13.8648, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 40
# tensor(13.7353, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 41
# tensor(13.6102, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 42
# tensor(13.4892, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 43
# tensor(13.3724, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 44
# tensor(13.2595, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 45
# tensor(13.1505, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 46
# tensor(13.0452, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 47
# tensor(12.9436, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 48
# tensor(12.8456, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 49
# tensor(12.7510, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 50
# tensor(12.6599, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 51
# tensor(12.5723, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 52
# tensor(12.4879, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 53
# tensor(12.4068, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 54
# tensor(12.3290, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 55
# tensor(12.2543, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 56
# tensor(12.1829, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 57
# tensor(12.1145, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 58
# tensor(12.0493, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 59
# tensor(11.9871, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 60
# tensor(11.9279, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 61
# tensor(11.8716, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 62
# tensor(11.8183, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 63
# tensor(11.7679, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 64
# tensor(11.7203, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 65
# tensor(11.6754, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 66
# tensor(11.6332, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 67
# tensor(11.5937, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 68
# tensor(11.5567, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 69
# tensor(11.5222, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 70
# tensor(11.4900, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 71
# tensor(11.4601, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 72
# tensor(11.4325, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 73
# tensor(11.4069, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 74
# tensor(11.3834, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 75
# tensor(11.3617, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 76
# tensor(11.3419, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 77
# tensor(11.3237, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 78
# tensor(11.3071, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 79
# tensor(11.2920, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 80
# tensor(11.2783, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 81
# tensor(11.2659, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 82
# tensor(11.2547, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 83
# tensor(11.2445, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 84
# tensor(11.2354, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 85
# tensor(11.2272, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 86
# tensor(11.2199, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 87
# tensor(11.2133, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 88
# tensor(11.2075, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 89
# tensor(11.2023, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 90
# tensor(11.1976, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 91
# tensor(11.1935, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 92
# tensor(11.1898, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 93
# tensor(11.1866, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 94
# tensor(11.1837, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 95
# tensor(11.1812, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 96
# tensor(11.1790, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 97
# tensor(11.1770, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 98
# tensor(11.1753, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 99
# tensor(11.1738, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 100
# tensor(11.1724, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 101
# tensor(11.1713, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 102
# tensor(11.1702, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 103
# tensor(11.1693, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 104
# tensor(11.1685, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 105
# tensor(11.1679, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 106
# tensor(11.1673, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 107
# tensor(11.1667, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 108
# tensor(11.1663, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 109
# tensor(11.1659, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 110
# tensor(11.1655, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 111
# tensor(11.1652, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 112
# tensor(11.1650, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 113
# tensor(11.1648, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 114
# tensor(11.1646, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 115
# tensor(11.1644, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 116
# tensor(11.1642, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 117
# tensor(11.1641, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 118
# tensor(11.1640, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 119
# tensor(11.1639, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 120
# tensor(11.1638, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 121
# tensor(11.1637, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 122
# tensor(11.1637, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 123
# tensor(11.1636, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 124
# tensor(11.1636, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 125
# tensor(11.1635, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 126
# tensor(11.1635, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 127
# tensor(11.1635, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 128
# tensor(11.1634, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 129
# tensor(11.1634, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 130
# tensor(11.1634, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 131
# tensor(11.1634, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 132
# tensor(11.1634, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 133
# tensor(11.1634, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 134
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 135
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 136
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 137
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 138
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 139
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 140
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 141
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 142
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 143
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 144
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 145
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 146
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 147
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 148
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 149
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 150
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 151
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 152
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 153
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 154
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 155
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 156
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 157
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 158
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 159
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 160
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 161
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 162
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 163
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 164
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 165
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 166
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 167
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 168
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 169
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 170
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 171
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 172
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 173
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 174
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 175
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 176
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 177
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 178
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 179
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 180
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 181
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 182
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 183
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 184
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 185
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 186
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 187
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 188
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 189
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 190
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 191
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 192
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 193
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 194
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 195
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 196
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 197
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 198
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 199
# tensor(11.1633, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 0
# tensor(44.1493, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 1
# tensor(32.4309, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 2
# tensor(31.4180, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 3
# tensor(30.4453, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 4
# tensor(29.5111, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 5
# tensor(28.6138, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 6
# tensor(27.7521, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 7
# tensor(26.9246, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 8
# tensor(26.1298, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 9
# tensor(25.3664, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 10
# tensor(24.6333, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 11
# tensor(23.9293, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 12
# tensor(23.2531, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 13
# tensor(22.6037, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 14
# tensor(21.9800, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 15
# tensor(21.3810, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 16
# tensor(20.8057, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 17
# tensor(20.2532, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 18
# tensor(19.7226, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 19
# tensor(19.2130, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 20
# tensor(18.7236, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 21
# tensor(18.2535, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 22
# tensor(17.8021, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 23
# tensor(17.3685, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 24
# tensor(16.9521, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 25
# tensor(16.5522, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 26
# tensor(16.1682, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 27
# tensor(15.7993, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 28
# tensor(15.4451, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 29
# tensor(15.1049, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 30
# tensor(14.7781, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 31
# tensor(14.4643, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 32
# tensor(14.1630, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 33
# tensor(13.8735, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 34
# tensor(13.5955, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 35
# tensor(13.3286, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 36
# tensor(13.0722, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 37
# tensor(12.8259, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 38
# tensor(12.5894, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 39
# tensor(12.3623, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 40
# tensor(12.1441, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 41
# tensor(11.9346, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 42
# tensor(11.7334, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 43
# tensor(11.5402, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 44
# tensor(11.3546, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 45
# tensor(11.1764, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 46
# tensor(11.0052, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 47
# tensor(10.8408, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 48
# tensor(10.6829, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 49
# tensor(10.5313, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 50
# tensor(10.3857, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 51
# tensor(10.2458, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 52
# tensor(10.1115, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 53
# tensor(9.9825, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 54
# tensor(9.8586, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 55
# tensor(9.7396, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 56
# tensor(9.6253, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 57
# tensor(9.5156, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 58
# tensor(9.4102, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 59
# tensor(9.3089, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 60
# tensor(9.2117, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 61
# tensor(9.1183, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 62
# tensor(9.0287, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 63
# tensor(8.9425, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 64
# tensor(8.8598, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 65
# tensor(8.7804, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 66
# tensor(8.7041, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 67
# tensor(8.6308, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 68
# tensor(8.5604, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 69
# tensor(8.4929, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 70
# tensor(8.4279, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 71
# tensor(8.3656, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 72
# tensor(8.3057, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 73
# tensor(8.2482, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 74
# tensor(8.1930, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 75
# tensor(8.1400, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 76
# tensor(8.0891, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 77
# tensor(8.0401, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 78
# tensor(7.9932, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 79
# tensor(7.9480, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 80
# tensor(7.9047, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 81
# tensor(7.8631, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 82
# tensor(7.8231, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 83
# tensor(7.7847, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 84
# tensor(7.7479, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 85
# tensor(7.7125, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 86
# tensor(7.6785, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 87
# tensor(7.6458, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 88
# tensor(7.6144, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 89
# tensor(7.5843, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 90
# tensor(7.5554, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 91
# tensor(7.5276, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 92
# tensor(7.5009, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 93
# tensor(7.4753, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 94
# tensor(7.4507, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 95
# tensor(7.4270, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 96
# tensor(7.4043, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 97
# tensor(7.3825, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 98
# tensor(7.3616, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 99
# tensor(7.3415, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 100
# tensor(7.3222, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 101
# tensor(7.3036, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 102
# tensor(7.2858, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 103
# tensor(7.2687, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 104
# tensor(7.2523, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 105
# tensor(7.2365, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 106
# tensor(7.2213, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 107
# tensor(7.2068, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 108
# tensor(7.1928, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 109
# tensor(7.1794, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 110
# tensor(7.1665, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 111
# tensor(7.1541, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 112
# tensor(7.1422, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 113
# tensor(7.1308, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 114
# tensor(7.1198, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 115
# tensor(7.1093, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 116
# tensor(7.0992, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 117
# tensor(7.0895, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 118
# tensor(7.0801, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 119
# tensor(7.0712, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 120
# tensor(7.0625, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 121
# tensor(7.0543, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 122
# tensor(7.0463, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 123
# tensor(7.0387, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 124
# tensor(7.0314, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 125
# tensor(7.0244, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 126
# tensor(7.0176, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 127
# tensor(7.0111, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 128
# tensor(7.0049, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 129
# tensor(6.9989, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 130
# tensor(6.9932, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 131
# tensor(6.9876, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 132
# tensor(6.9823, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 133
# tensor(6.9772, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 134
# tensor(6.9724, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 135
# tensor(6.9677, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 136
# tensor(6.9632, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 137
# tensor(6.9588, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 138
# tensor(6.9547, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 139
# tensor(6.9507, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 140
# tensor(6.9468, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 141
# tensor(6.9431, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 142
# tensor(6.9396, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 143
# tensor(6.9362, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 144
# tensor(6.9329, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 145
# tensor(6.9298, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 146
# tensor(6.9268, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 147
# tensor(6.9239, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 148
# tensor(6.9211, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 149
# tensor(6.9185, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 150
# tensor(6.9159, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 151
# tensor(6.9134, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 152
# tensor(6.9111, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 153
# tensor(6.9088, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 154
# tensor(6.9066, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 155
# tensor(6.9045, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 156
# tensor(6.9025, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 157
# tensor(6.9006, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 158
# tensor(6.8987, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 159
# tensor(6.8970, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 160
# tensor(6.8953, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 161
# tensor(6.8936, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 162
# tensor(6.8920, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 163
# tensor(6.8905, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 164
# tensor(6.8891, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 165
# tensor(6.8877, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 166
# tensor(6.8863, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 167
# tensor(6.8850, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 168
# tensor(6.8838, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 169
# tensor(6.8826, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 170
# tensor(6.8815, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 171
# tensor(6.8804, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 172
# tensor(6.8793, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 173
# tensor(6.8783, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 174
# tensor(6.8773, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 175
# tensor(6.8764, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 176
# tensor(6.8755, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 177
# tensor(6.8746, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 178
# tensor(6.8738, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 179
# tensor(6.8730, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 180
# tensor(6.8723, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 181
# tensor(6.8715, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 182
# tensor(6.8708, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 183
# tensor(6.8702, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 184
# tensor(6.8695, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 185
# tensor(6.8689, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 186
# tensor(6.8683, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 187
# tensor(6.8677, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 188
# tensor(6.8672, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 189
# tensor(6.8666, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 190
# tensor(6.8661, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 191
# tensor(6.8656, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 192
# tensor(6.8652, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 193
# tensor(6.8647, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 194
# tensor(6.8643, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 195
# tensor(6.8639, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 196
# tensor(6.8635, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 197
# tensor(6.8631, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 198
# tensor(6.8627, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 199
# tensor(6.8624, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 0
# tensor(16.4259, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 1
# tensor(6754.1142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 2
# tensor(61.2399, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 3
# tensor(46.5957, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 4
# tensor(44.0853, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 5
# tensor(41.6521, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 6
# tensor(39.2405, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 7
# tensor(36.8058, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 8
# tensor(34.3113, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 9
# tensor(31.7283, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 10
# tensor(29.0377, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 11
# tensor(26.2335, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 12
# tensor(23.3289, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 13
# tensor(20.3624, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 14
# tensor(17.4047, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 15
# tensor(14.5602, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 16
# tensor(11.9589, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 17
# tensor(9.7327, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 18
# tensor(7.9793, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 19
# tensor(6.7284, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 20
# tensor(5.9237, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 21
# tensor(5.4586, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 22
# tensor(5.2153, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 23
# tensor(5.0984, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 24
# tensor(5.0459, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 25
# tensor(5.0235, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 26
# tensor(5.0142, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 27
# tensor(5.0105, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 28
# tensor(5.0090, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 29
# tensor(5.0084, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 30
# tensor(5.0082, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 31
# tensor(5.0081, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 32
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 33
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 34
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 35
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 36
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 37
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 38
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 39
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 40
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 41
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 42
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 43
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 44
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 45
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 46
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 47
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 48
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 49
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 50
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 51
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 52
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 53
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 54
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 55
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 56
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 57
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 58
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 59
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 60
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 61
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 62
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 63
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 64
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 65
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 66
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 67
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 68
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 69
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 70
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 71
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 72
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 73
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 74
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 75
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 76
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 77
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 78
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 79
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 80
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 81
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 82
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 83
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 84
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 85
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 86
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 87
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 88
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 89
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 90
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 91
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 92
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 93
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 94
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 95
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 96
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 97
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 98
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 99
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 100
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 101
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 102
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 103
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 104
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 105
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 106
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 107
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 108
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 109
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 110
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 111
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 112
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 113
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 114
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 115
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 116
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 117
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 118
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 119
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 120
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 121
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 122
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 123
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 124
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 125
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 126
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 127
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 128
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 129
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 130
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 131
# tensor(5.0080, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 132
# ...
# 154
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 155
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 156
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 157
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 158
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 159
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 160
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 161
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 162
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 163
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 164
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 165
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 166
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 167
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 168
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 169
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 170
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 171
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 172
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 173
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 174
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 175
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 176
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 177
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 178
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 179
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 180
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 181
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 182
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 183
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 184
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 185
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 186
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 187
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 188
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 189
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 190
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 191
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 192
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 193
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 194
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 195
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 196
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 197
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 198
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 199
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 0
# tensor(28.7463, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 1
# tensor(3661.8660, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 2
# tensor(58.7550, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 3
# tensor(56.4293, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 4
# tensor(54.1957, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 5
# tensor(52.0506, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 6
# tensor(49.9904, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 7
# tensor(48.0118, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 8
# tensor(46.1115, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 9
# tensor(44.2865, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 10
# tensor(42.5337, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 11
# tensor(40.8504, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 12
# tensor(39.2337, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 13
# tensor(37.6811, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 14
# tensor(36.1899, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 15
# tensor(34.7578, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 16
# tensor(33.3824, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 17
# tensor(32.0615, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 18
# tensor(30.7928, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 19
# tensor(29.5744, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 20
# tensor(28.4043, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 21
# tensor(27.2805, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 22
# tensor(26.2012, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 23
# tensor(25.1646, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 24
# tensor(24.1691, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 25
# tensor(23.2130, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 26
# tensor(22.2948, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 27
# tensor(21.4129, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 28
# tensor(20.5660, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 29
# tensor(19.7526, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 30
# tensor(18.9714, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 31
# tensor(18.2211, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 32
# tensor(17.5005, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 33
# tensor(16.8085, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 34
# tensor(16.1439, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 35
# tensor(15.5056, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 36
# tensor(14.8926, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 37
# tensor(14.3039, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 38
# tensor(13.7384, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 39
# tensor(13.1954, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 40
# tensor(12.6739, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 41
# tensor(12.1730, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 42
# tensor(11.6919, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 43
# tensor(11.2299, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 44
# tensor(10.7862, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 45
# tensor(10.3601, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 46
# tensor(9.9509, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 47
# tensor(9.5578, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 48
# tensor(9.1803, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 49
# tensor(8.8178, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 50
# tensor(8.4696, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 51
# tensor(8.1352, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 52
# tensor(7.8141, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 53
# tensor(7.5056, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 54
# tensor(7.2094, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 55
# tensor(6.9249, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 56
# tensor(6.6517, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 57
# tensor(6.3893, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 58
# tensor(6.1373, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 59
# tensor(5.8952, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 60
# tensor(5.6628, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 61
# tensor(5.4396, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 62
# tensor(5.2252, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 63
# tensor(5.0192, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 64
# tensor(4.8215, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 65
# tensor(4.6316, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 66
# tensor(4.4492, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 67
# tensor(4.2740, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 68
# tensor(4.1057, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 69
# tensor(3.9441, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 70
# tensor(3.7890, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 71
# tensor(3.6399, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 72
# tensor(3.4968, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 73
# tensor(3.3593, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 74
# tensor(3.2273, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 75
# tensor(3.1005, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 76
# tensor(2.9787, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 77
# tensor(2.8618, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 78
# tensor(2.7494, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 79
# tensor(2.6416, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 80
# tensor(2.5380, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 81
# tensor(2.4385, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 82
# tensor(2.3429, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 83
# tensor(2.2511, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 84
# tensor(2.1630, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 85
# tensor(2.0783, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 86
# tensor(1.9970, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 87
# tensor(1.9190, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 88
# tensor(1.8440, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 89
# tensor(1.7720, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 90
# tensor(1.7028, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 91
# tensor(1.6364, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 92
# tensor(1.5726, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 93
# tensor(1.5113, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 94
# tensor(1.4525, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 95
# tensor(1.3959, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 96
# tensor(1.3417, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 97
# tensor(1.2895, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 98
# tensor(1.2395, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 99
# tensor(1.1914, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 100
# tensor(1.1452, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 101
# tensor(1.1009, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 102
# tensor(1.0583, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 103
# tensor(1.0174, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 104
# tensor(0.9781, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 105
# tensor(0.9404, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 106
# tensor(0.9041, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 107
# tensor(0.8693, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 108
# tensor(0.8359, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 109
# tensor(0.8038, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 110
# tensor(0.7730, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 111
# tensor(0.7434, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 112
# tensor(0.7150, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 113
# tensor(0.6876, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 114
# tensor(0.6614, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 115
# tensor(0.6362, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 116
# tensor(0.6120, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 117
# tensor(0.5888, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 118
# tensor(0.5665, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 119
# tensor(0.5451, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 120
# tensor(0.5245, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 121
# tensor(0.5047, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 122
# tensor(0.4857, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 123
# tensor(0.4675, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 124
# tensor(0.4500, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 125
# tensor(0.4332, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 126
# tensor(0.4170, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 127
# tensor(0.4015, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 128
# tensor(0.3866, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 129
# tensor(0.3723, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 130
# tensor(0.3586, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 131
# tensor(0.3454, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 132
# tensor(0.3327, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 133
# tensor(0.3205, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 134
# tensor(0.3088, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 135
# tensor(0.2976, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 136
# tensor(0.2868, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 137
# tensor(0.2765, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 138
# tensor(0.2665, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 139
# tensor(0.2570, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 140
# tensor(0.2478, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 141
# tensor(0.2390, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 142
# tensor(0.2305, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 143
# tensor(0.2224, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 144
# tensor(0.2146, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 145
# tensor(0.2071, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 146
# tensor(0.1999, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 147
# tensor(0.1930, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 148
# tensor(0.1864, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 149
# tensor(0.1800, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 150
# tensor(0.1739, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 151
# tensor(0.1680, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 152
# tensor(0.1623, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 153
# tensor(0.1569, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 154
# tensor(0.1517, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 155
# tensor(0.1467, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 156
# tensor(0.1419, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 157
# tensor(0.1373, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 158
# tensor(0.1329, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 159
# tensor(0.1286, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 160
# tensor(0.1245, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 161
# tensor(0.1206, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 162
# tensor(0.1168, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 163
# tensor(0.1132, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 164
# tensor(0.1097, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 165
# tensor(0.1064, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 166
# tensor(0.1032, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 167
# tensor(0.1001, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 168
# tensor(0.0971, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 169
# tensor(0.0943, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 170
# tensor(0.0916, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 171
# tensor(0.0889, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 172
# tensor(0.0864, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 173
# tensor(0.0840, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 174
# tensor(0.0817, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 175
# tensor(0.0794, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 176
# tensor(0.0773, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 177
# tensor(0.0752, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 178
# tensor(0.0733, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 179
# tensor(0.0714, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 180
# tensor(0.0696, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 181
# tensor(0.0678, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 182
# tensor(0.0661, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 183
# tensor(0.0645, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 184
# tensor(0.0630, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 185
# tensor(0.0615, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 186
# tensor(0.0600, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 187
# tensor(0.0587, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 188
# tensor(0.0573, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 189
# tensor(0.0561, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 190
# tensor(0.0549, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 191
# tensor(0.0537, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 192
# tensor(0.0526, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 193
# tensor(0.0515, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 194
# tensor(0.0505, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 195
# tensor(0.0495, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 196
# tensor(0.0485, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 197
# tensor(0.0476, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 198
# tensor(0.0467, dtype=torch.float64, grad_fn=<MeanBackward0>)
# 199
# tensor(0.0459, dtype=torch.float64, grad_fn=<MeanBackward0>)
# tensor([6.6096])

# %%
print("Le prix d'un Put bermudéen avec réseaux de neurones est ", price[0].item(), "$")
# Out:
# Le prix d'un Put bermudéen avec réseaux de neurones est  6.609626293182373 $

# %% [markdown]
# Je remarque que en augmentant le nombre d'epochs ou le nombre de path M, le prix semble croitre et est meme supérieur à 2.6
#
# Mon modèle n'est donc pas stable et ne converge pas vers sa valeur théorique.
# Il y a donc sans doute une erreur d'implémentation.
